# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.rcParams["text.usetex"] = True
plt.rcParams["font.family"] = "serif"

# %%
# read csv

df = pd.read_csv('exercises1234.csv')

t1 = np.array(df.iloc[0])[1:].astype(float)
a1 = np.array(df.iloc[1])[1:].astype(float)
b1 = np.array(df.iloc[2])[1:].astype(float)
plt.plot(t1, a1, 'b-', label=r'$\alpha$')
plt.plot(t1, b1, 'r-', label=r'$\beta$')

plt.xlabel('Time [s]')
plt.ylabel('Angle [deg]')
plt.title('Mode 1 at 1.0575 Hz')
plt.legend()

# %%
t2 = np.array(df.iloc[7])[1:].astype(float)
a2 = np.array(df.iloc[8])[1:].astype(float)
b2 = np.array(df.iloc[9])[1:].astype(float)
plt.plot(t2, a2, 'b-', label=r'$\alpha$')
plt.plot(t2, b2, 'r-', label=r'$\beta$')

plt.xlabel('Time [s]')
plt.ylabel('Angle [deg]')
plt.title('Mode 2 at 0.1910 Hz')
plt.legend()

# %%
t3 = np.array(df.iloc[14])[1:].astype(float)
a3 = np.array(df.iloc[15])[1:].astype(float)
b3 = np.array(df.iloc[16])[1:].astype(float)
plt.plot(t3, a3, 'b-', label=r'$\alpha$')
plt.plot(t3, b3, 'r-', label=r'$\beta$')

plt.xlabel('Time [s]')
plt.ylabel('Angle [deg]')
plt.title('Mode 1 at 1.0847 Hz')
plt.legend()

# %%
t4 = np.array(df.iloc[21])[1:].astype(float)
a4 = np.array(df.iloc[22])[1:].astype(float)
b4 = np.array(df.iloc[23])[1:].astype(float)
plt.plot(t4, a4, 'b-', label=r'$\alpha$')
plt.plot(t4, b4, 'r-', label=r'$\beta$')

plt.xlabel('Time [s]')
plt.ylabel('Angle [deg]')
plt.title(r'$\beta_0 = 90\deg$')
plt.ylim(-180, 180)
plt.legend()

# %%
t5 = np.array(df.iloc[28])[1:].astype(float)
a5 = np.array(df.iloc[29])[1:].astype(float)
b5 = np.array(df.iloc[30])[1:].astype(float)
plt.plot(t5, a5, 'b-', label=r'$\alpha$')
plt.plot(t5, b5, 'r-', label=r'$\beta$')
plt.legend()

plt.xlabel('Time [s]')
plt.ylabel('Angle [deg]')
plt.title(r'$\alpha_0 = 90\deg$')
plt.ylim(-180, 180)
plt.legend()

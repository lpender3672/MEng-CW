# %%
import numpy as np
import sympy as sym
import control as ctrl
from matplotlib import pyplot as plt

# %%
t = np.linspace(0, 5, 100)
omega = 1*np.pi
xdot = np.sin(omega * t)

plt.plot(t, xdot)
plt.plot(t, np.sign(xdot))

plt.grid()

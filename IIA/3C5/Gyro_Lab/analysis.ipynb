# %%
import numpy as np 
import matplotlib.pyplot as plt

plt.rcParams["text.usetex"] = True
plt.rcParams["font.family"] = "serif"
plt.rcParams['figure.facecolor'] = 'white'

# %%
# load nutation data
nutation = np.loadtxt('nutation_data.txt')
print(nutation.shape)
# Out:
# (15, 5)

# %%
# plot
plt.scatter(nutation[:,1], nutation[:,2], label = r'$f_{meas}$', marker='x')
plt.scatter(nutation[:,1], nutation[:,4], label = r'$f_{(A7)}$', marker='d')

plt.xlabel(r'$\theta$ [$^o$]')
plt.ylabel(r'Frequency [Hz]')
plt.legend( loc='lower left', prop={'size': 12})
plt.grid()
# set ticks
plt.xticks(np.arange(90, 151, 15))
plt.ylim(0, 20)

plt.savefig("nutation.png", dpi=300)
plt.show()

# %%
# load cuspidal nutation data
cuspidal_nutation = np.loadtxt('cuspidal_nutation_data.txt')
print(cuspidal_nutation.shape)
# Out:
# (9, 5)

# %%
# plot
plt.scatter(cuspidal_nutation[:,1], cuspidal_nutation[:,3], marker="x")

plt.xlabel(r'$\theta$ [$^o$]')
plt.ylabel(r'Frequency [Hz]')
plt.grid()
# set ticks

plt.savefig("cuspidal_nutation.png", dpi=300)
plt.show()
